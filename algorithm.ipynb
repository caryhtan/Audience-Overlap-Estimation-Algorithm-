# %%
import pandas as pd
import numpy as np
import ast
"""
Estimate audience overlap across multiple demographic characteristics.

Steps:
1. Load and merge demographic and visitor data.
2. Calculate lower bounds for audience estimates.
3. Apply overlap estimation algorithm for each demographic characteristic.
4. Save results to a CSV file.
"""
# Out:
# '\nEstimate audience overlap across multiple demographic characteristics.\n\nSteps:\n1. Load and merge demographic and visitor data.\n2. Calculate lower bounds for audience estimates.\n3. Apply overlap estimation algorithm for each demographic characteristic.\n4. Save results to a CSV file.\n'

# %%
# Step 1: Data Preprocessing/loading data from the datasets
"""
Load demographic and visitor data from CSV files, merge them based on 'tag' and 'date' columns.
"""

demo_data = pd.read_csv("./input/demo.csv")
visitors_data = pd.read_csv('./input/all_visitors.csv')
merged_data = pd.merge(demo_data, visitors_data, on=['tag', 'date'])
# print(demo_data)
# print(visitors_data )
print(merged_data)
# Out:
#                tag        date  \
# 0             AIF/  2022-12-01
# 1             AIF/  2022-12-02
# 2             AIF/  2022-12-03
# 3             AIF/  2022-12-04
# 4             AIF/  2022-12-05
# ..             ...         ...
# 88  kommersant.ru/  2022-12-27
# 89  kommersant.ru/  2022-12-28
# 90  kommersant.ru/  2022-12-29
# 91  kommersant.ru/  2022-12-30
# 92  kommersant.ru/  2022-12-31
#
#                                                  demo  \
# 0   {'Men above 45': 270578.0, 'Men 25-34': 248189...
# 1   {'Men above 45': 242880.0, 'Men 25-34': 218607...
# 2   {'Men above 45': 215736.0, 'Men 25-34': 195687...
# 3   {'Men above 45': 205517.0, 'Men 25-34': 181038...
# 4   {'Men above 45': 215976.0, 'Men 25-34': 207819...
# ..                                                ...
# 88  {'Men 25-34': 327395.0, 'Men 18-24': 273582.0,...
# 89  {'Men 25-34': 318169.0, 'Men 18-24': 265664.0,...
# 90  {'Men 25-34': 337351.0, 'Men 18-24': 299877.0,...
# 91  {'Men 25-34': 315727.0, 'Men 18-24': 275097.0,...
# 92  {'Men 25-34': 262995.0, 'Men 18-24': 260051.0,...
#
#                                      visitors_country  \
# 0   {'Russia': 1211629.0, 'Belarus': 43368.0, 'Mol...
# 1   {'Russia': 1057284.0, 'Belarus': 38382.0, 'Mol...
# 2   {'Russia': 958308.0, 'Belarus': 29036.0, 'Germ...
# 3   {'Russia': 928436.0, 'Belarus': 29028.0, 'Germ...
# 4   {'Russia': 1013907.0, 'Belarus': 33451.0, 'Ger...
# ..                                                ...
# 88  {'Russia': 1071239.0, 'Germany': 36767.0, 'Kaz...
# 89  {'Russia': 1037375.0, 'Germany': 30909.0, 'Kaz...
# 90  {'Russia': 1180170.0, 'Germany': 28487.0, 'Bel...
# 91  {'Russia': 1087416.0, 'Germany': 25042.0, 'Bel...
# 92  {'Russia': 894736.0, 'Germany': 28130.0, 'Kaza...
#
#                                     pageviews_country  \
# 0   {'Russia': 2071161.0, 'Belarus': 99644.0, 'Ger...
# 1   {'Russia': 1903844.0, 'Belarus': 89485.0, 'Ger...
# 2   {'Russia': 1621842.0, 'Belarus': 66206.0, 'Ger...
# 3   {'Russia': 1552619.0, 'Belarus': 64692.0, 'Ger...
# 4   {'Russia': 1773680.0, 'Belarus': 76641.0, 'Ger...
# ..                                                ...
# 88  {'Russia': 2970611.0, 'Germany': 89989.0, 'Kaz...
# 89  {'Russia': 3000778.0, 'Germany': 78984.0, 'Bel...
# 90  {'Russia': 3577859.0, 'Germany': 78038.0, 'Bel...
# 91  {'Russia': 2899811.0, 'Germany': 66364.0, 'Bel...
# 92  {'Russia': 2360797.0, 'Germany': 73537.0, 'Bel...
#
#                                       visitors_region  \
# 0   {'Moscow': 440317.0, 'Saint-Petersburg': 10263...
# 1   {'Moscow': 386111.0, 'Saint-Petersburg': 83658...
# 2   {'Moscow': 341031.0, 'Saint-Petersburg': 82148...
# 3   {'Moscow': 314441.0, 'Saint-Petersburg': 80364...
# 4   {'Moscow': 355392.0, 'Saint-Petersburg': 90001...
# ..                                                ...
# 88  {'Moscow': 406660.0, 'Saint-Petersburg': 10042...
# 89  {'Moscow': 395353.0, 'Saint-Petersburg': 93811...
# 90  {'Moscow': 442885.0, 'Saint-Petersburg': 10657...
# 91  {'Moscow': 410355.0, 'Saint-Petersburg': 10432...
# 92  {'Moscow': 352865.0, 'Saint-Petersburg': 94029...
#
#                                      pageviews_region providers  \
# 0   {'Moscow': 720227.0, 'Saint-Petersburg': 16491...        {}
# 1   {'Moscow': 677121.0, 'Saint-Petersburg': 14202...        {}
# 2   {'Moscow': 559168.0, 'Saint-Petersburg': 13500...        {}
# 3   {'Moscow': 517002.0, 'Saint-Petersburg': 12590...        {}
# 4   {'Moscow': 598747.0, 'Saint-Petersburg': 14990...        {}
# ..                                                ...       ...
# 88  {'Moscow': 1170449.0, 'Saint-Petersburg': 2778...        {}
# 89  {'Moscow': 1223988.0, 'Saint-Petersburg': 2705...        {}
# 90  {'Moscow': 1392630.0, 'Saint-Petersburg': 3281...        {}
# 91  {'Moscow': 1143339.0, 'Saint-Petersburg': 2780...        {}
# 92  {'Moscow': 952181.0, 'Saint-Petersburg': 23026...        {}
#
#                                             languages  \
# 0   {'Russian, Russia [ru-ru]': 1030640.0, 'Russia...
# 1   {'Russian, Russia [ru-ru]': 908252.0, 'Russian...
# 2   {'Russian, Russia [ru-ru]': 842346.0, 'Russian...
# 3   {'Russian, Russia [ru-ru]': 801234.0, 'Russian...
# 4   {'Russian, Russia [ru-ru]': 867459.0, 'Russian...
# ..                                                ...
# 88                                                 {}
# 89                                                 {}
# 90                                                 {}
# 91                                                 {}
# 92                                                 {}
#
#                                              browsers  \
# 0   {'Yandex.Browser': 620660.0, 'Google Chrome': ...
# 1   {'Yandex.Browser': 526404.0, 'Google Chrome': ...
# 2   {'Yandex.Browser': 512079.0, 'Google Chrome': ...
# 3   {'Yandex.Browser': 460358.0, 'Google Chrome': ...
# 4   {'Yandex.Browser': 481931.0, 'Google Chrome': ...
# ..                                                ...
# 88  {'Google Chrome': 758289.0, 'Yandex.Browser': ...
# 89  {'Google Chrome': 677120.0, 'Yandex.Browser': ...
# 90  {'Google Chrome': 810986.0, 'Yandex.Browser': ...
# 91  {'Google Chrome': 750989.0, 'Yandex.Browser': ...
# 92  {'Google Chrome': 720182.0, 'Yandex.Browser': ...
#
#                                                  oses  \
# 0   {'Android': 884351.0, 'Windows 10': 209542.0, ...
# 1   {'Android': 769752.0, 'Windows 10': 194383.0, ...
# 2   {'Android': 773743.0, 'Windows 10': 121636.0, ...
# 3   {'Android': 739112.0, 'Windows 10': 120993.0, ...
# 4   {'Android': 764645.0, 'Windows 10': 157292.0, ...
# ..                                                ...
# 88  {'Android': 870909.0, 'Windows 10': 167845.0, ...
# 89  {'Android': 838818.0, 'Windows 10': 152296.0, ...
# 90  {'Android': 982592.0, 'Windows 10': 155330.0, ...
# 91  {'Android': 908596.0, 'iOS iPhone': 146384.0, ...
# 92  {'Android': 804632.0, 'iOS iPhone': 112135.0, ...
#
#                                           resolutions  \
# 0   {'Undefined': 452746.0, '1024×768': 347448.0, ...
# 1   {'Undefined': 409074.0, '1024×768': 297001.0, ...
# 2   {'1024×768': 328422.0, 'Undefined': 300725.0, ...
# 3   {'Undefined': 362974.0, '1024×768': 289840.0, ...
# 4   {'Undefined': 341916.0, '1024×768': 333472.0, ...
# ..                                                ...
# 88  {'1024×768': 500760.0, '800×600': 393276.0, '6...
# 89  {'1024×768': 476682.0, '800×600': 373745.0, '6...
# 90  {'1024×768': 535792.0, '800×600': 454009.0, '6...
# 91  {'1024×768': 513139.0, '800×600': 408517.0, '6...
# 92  {'1024×768': 461333.0, '800×600': 350683.0, '6...
#
#                                                colors   Visitors
# 0   {'16 million': 929225.0, 'Undefined': 452848.0...  1387448.0
# 1   {'16 million': 809445.0, 'Undefined': 409163.0...  1224443.0
# 2   {'16 million': 804662.0, 'Undefined': 300822.0...  1108391.0
# 3   {'16 million': 703141.0, 'Undefined': 363046.0...  1071513.0
# 4   {'16 million': 828281.0, 'Undefined': 341998.0...  1174182.0
# ..                                                ...        ...
# 88  {'16 million': 1258572.0, 'Undefined': 44215.0...  1306594.0
# 89  {'16 million': 1175521.0, 'Undefined': 58172.0...  1237120.0
# 90  {'16 million': 1347908.0, 'Undefined': 34458.0...  1385526.0
# 91  {'16 million': 1216414.0, 'Undefined': 52606.0...  1273358.0
# 92  {'16 million': 1034117.0, 'Undefined': 32206.0...  1074313.0
#
# [93 rows x 14 columns]

# %%
# Step 2: Calculate Lower Bounds
"""
Calculate the lower bound of audience size for each row in the merged data.
"""
def calculate_lower_bound(row):
    try:
        """
        Calculates the lower bound of audience size for a given row.

        Args:
            row (pandas.Series): A row of data containing 'demo' and 'Visitors' values.
    
        Returns:
            int: The maximum value between 'demo' and 'Visitors', representing the lower bound.
        """
        demo_dict = ast.literal_eval(row['demo'])
        
        # Extract the relevant values from the 'demo' dictionary
        demo_value = sum(demo_dict.values())  # Summing up all values in the dictionary
        
        # Convert the 'Visitors' value to float
        visitors_value = float(row['Visitors'])
        
        # Implement the lower bound calculation based on the formula
        return max(demo_value, visitors_value)
    
    except (ValueError, TypeError, SyntaxError):
        # Handle the case where conversion to float fails or 'demo' is not in the expected format
        return np.nan  # or any default value

# Apply the calculate_lower_bound function to create the 'lower_bound' column
merged_data['lower_bound'] = merged_data.apply(calculate_lower_bound, axis=1)
print(merged_data)
# Out:
#                tag        date  \
# 0             AIF/  2022-12-01
# 1             AIF/  2022-12-02
# 2             AIF/  2022-12-03
# 3             AIF/  2022-12-04
# 4             AIF/  2022-12-05
# ..             ...         ...
# 88  kommersant.ru/  2022-12-27
# 89  kommersant.ru/  2022-12-28
# 90  kommersant.ru/  2022-12-29
# 91  kommersant.ru/  2022-12-30
# 92  kommersant.ru/  2022-12-31
#
#                                                  demo  \
# 0   {'Men above 45': 270578.0, 'Men 25-34': 248189...
# 1   {'Men above 45': 242880.0, 'Men 25-34': 218607...
# 2   {'Men above 45': 215736.0, 'Men 25-34': 195687...
# 3   {'Men above 45': 205517.0, 'Men 25-34': 181038...
# 4   {'Men above 45': 215976.0, 'Men 25-34': 207819...
# ..                                                ...
# 88  {'Men 25-34': 327395.0, 'Men 18-24': 273582.0,...
# 89  {'Men 25-34': 318169.0, 'Men 18-24': 265664.0,...
# 90  {'Men 25-34': 337351.0, 'Men 18-24': 299877.0,...
# 91  {'Men 25-34': 315727.0, 'Men 18-24': 275097.0,...
# 92  {'Men 25-34': 262995.0, 'Men 18-24': 260051.0,...
#
#                                      visitors_country  \
# 0   {'Russia': 1211629.0, 'Belarus': 43368.0, 'Mol...
# 1   {'Russia': 1057284.0, 'Belarus': 38382.0, 'Mol...
# 2   {'Russia': 958308.0, 'Belarus': 29036.0, 'Germ...
# 3   {'Russia': 928436.0, 'Belarus': 29028.0, 'Germ...
# 4   {'Russia': 1013907.0, 'Belarus': 33451.0, 'Ger...
# ..                                                ...
# 88  {'Russia': 1071239.0, 'Germany': 36767.0, 'Kaz...
# 89  {'Russia': 1037375.0, 'Germany': 30909.0, 'Kaz...
# 90  {'Russia': 1180170.0, 'Germany': 28487.0, 'Bel...
# 91  {'Russia': 1087416.0, 'Germany': 25042.0, 'Bel...
# 92  {'Russia': 894736.0, 'Germany': 28130.0, 'Kaza...
#
#                                     pageviews_country  \
# 0   {'Russia': 2071161.0, 'Belarus': 99644.0, 'Ger...
# 1   {'Russia': 1903844.0, 'Belarus': 89485.0, 'Ger...
# 2   {'Russia': 1621842.0, 'Belarus': 66206.0, 'Ger...
# 3   {'Russia': 1552619.0, 'Belarus': 64692.0, 'Ger...
# 4   {'Russia': 1773680.0, 'Belarus': 76641.0, 'Ger...
# ..                                                ...
# 88  {'Russia': 2970611.0, 'Germany': 89989.0, 'Kaz...
# 89  {'Russia': 3000778.0, 'Germany': 78984.0, 'Bel...
# 90  {'Russia': 3577859.0, 'Germany': 78038.0, 'Bel...
# 91  {'Russia': 2899811.0, 'Germany': 66364.0, 'Bel...
# 92  {'Russia': 2360797.0, 'Germany': 73537.0, 'Bel...
#
#                                       visitors_region  \
# 0   {'Moscow': 440317.0, 'Saint-Petersburg': 10263...
# 1   {'Moscow': 386111.0, 'Saint-Petersburg': 83658...
# 2   {'Moscow': 341031.0, 'Saint-Petersburg': 82148...
# 3   {'Moscow': 314441.0, 'Saint-Petersburg': 80364...
# 4   {'Moscow': 355392.0, 'Saint-Petersburg': 90001...
# ..                                                ...
# 88  {'Moscow': 406660.0, 'Saint-Petersburg': 10042...
# 89  {'Moscow': 395353.0, 'Saint-Petersburg': 93811...
# 90  {'Moscow': 442885.0, 'Saint-Petersburg': 10657...
# 91  {'Moscow': 410355.0, 'Saint-Petersburg': 10432...
# 92  {'Moscow': 352865.0, 'Saint-Petersburg': 94029...
#
#                                      pageviews_region providers  \
# 0   {'Moscow': 720227.0, 'Saint-Petersburg': 16491...        {}
# 1   {'Moscow': 677121.0, 'Saint-Petersburg': 14202...        {}
# 2   {'Moscow': 559168.0, 'Saint-Petersburg': 13500...        {}
# 3   {'Moscow': 517002.0, 'Saint-Petersburg': 12590...        {}
# 4   {'Moscow': 598747.0, 'Saint-Petersburg': 14990...        {}
# ..                                                ...       ...
# 88  {'Moscow': 1170449.0, 'Saint-Petersburg': 2778...        {}
# 89  {'Moscow': 1223988.0, 'Saint-Petersburg': 2705...        {}
# 90  {'Moscow': 1392630.0, 'Saint-Petersburg': 3281...        {}
# 91  {'Moscow': 1143339.0, 'Saint-Petersburg': 2780...        {}
# 92  {'Moscow': 952181.0, 'Saint-Petersburg': 23026...        {}
#
#                                             languages  \
# 0   {'Russian, Russia [ru-ru]': 1030640.0, 'Russia...
# 1   {'Russian, Russia [ru-ru]': 908252.0, 'Russian...
# 2   {'Russian, Russia [ru-ru]': 842346.0, 'Russian...
# 3   {'Russian, Russia [ru-ru]': 801234.0, 'Russian...
# 4   {'Russian, Russia [ru-ru]': 867459.0, 'Russian...
# ..                                                ...
# 88                                                 {}
# 89                                                 {}
# 90                                                 {}
# 91                                                 {}
# 92                                                 {}
#
#                                              browsers  \
# 0   {'Yandex.Browser': 620660.0, 'Google Chrome': ...
# 1   {'Yandex.Browser': 526404.0, 'Google Chrome': ...
# 2   {'Yandex.Browser': 512079.0, 'Google Chrome': ...
# 3   {'Yandex.Browser': 460358.0, 'Google Chrome': ...
# 4   {'Yandex.Browser': 481931.0, 'Google Chrome': ...
# ..                                                ...
# 88  {'Google Chrome': 758289.0, 'Yandex.Browser': ...
# 89  {'Google Chrome': 677120.0, 'Yandex.Browser': ...
# 90  {'Google Chrome': 810986.0, 'Yandex.Browser': ...
# 91  {'Google Chrome': 750989.0, 'Yandex.Browser': ...
# 92  {'Google Chrome': 720182.0, 'Yandex.Browser': ...
#
#                                                  oses  \
# 0   {'Android': 884351.0, 'Windows 10': 209542.0, ...
# 1   {'Android': 769752.0, 'Windows 10': 194383.0, ...
# 2   {'Android': 773743.0, 'Windows 10': 121636.0, ...
# 3   {'Android': 739112.0, 'Windows 10': 120993.0, ...
# 4   {'Android': 764645.0, 'Windows 10': 157292.0, ...
# ..                                                ...
# 88  {'Android': 870909.0, 'Windows 10': 167845.0, ...
# 89  {'Android': 838818.0, 'Windows 10': 152296.0, ...
# 90  {'Android': 982592.0, 'Windows 10': 155330.0, ...
# 91  {'Android': 908596.0, 'iOS iPhone': 146384.0, ...
# 92  {'Android': 804632.0, 'iOS iPhone': 112135.0, ...
#
#                                           resolutions  \
# 0   {'Undefined': 452746.0, '1024×768': 347448.0, ...
# 1   {'Undefined': 409074.0, '1024×768': 297001.0, ...
# 2   {'1024×768': 328422.0, 'Undefined': 300725.0, ...
# 3   {'Undefined': 362974.0, '1024×768': 289840.0, ...
# 4   {'Undefined': 341916.0, '1024×768': 333472.0, ...
# ..                                                ...
# 88  {'1024×768': 500760.0, '800×600': 393276.0, '6...
# 89  {'1024×768': 476682.0, '800×600': 373745.0, '6...
# 90  {'1024×768': 535792.0, '800×600': 454009.0, '6...
# 91  {'1024×768': 513139.0, '800×600': 408517.0, '6...
# 92  {'1024×768': 461333.0, '800×600': 350683.0, '6...
#
#                                                colors   Visitors  lower_bound
# 0   {'16 million': 929225.0, 'Undefined': 452848.0...  1387448.0    1387448.0
# 1   {'16 million': 809445.0, 'Undefined': 409163.0...  1224443.0    1224443.0
# 2   {'16 million': 804662.0, 'Undefined': 300822.0...  1108391.0    1108391.0
# 3   {'16 million': 703141.0, 'Undefined': 363046.0...  1071513.0    1071513.0
# 4   {'16 million': 828281.0, 'Undefined': 341998.0...  1174182.0    1174182.0
# ..                                                ...        ...          ...
# 88  {'16 million': 1258572.0, 'Undefined': 44215.0...  1306594.0    1306594.0
# 89  {'16 million': 1175521.0, 'Undefined': 58172.0...  1237120.0    1237120.0
# 90  {'16 million': 1347908.0, 'Undefined': 34458.0...  1385526.0    1385526.0
# 91  {'16 million': 1216414.0, 'Undefined': 52606.0...  1273358.0    1273358.0
# 92  {'16 million': 1034117.0, 'Undefined': 32206.0...  1074313.0    1074313.0
#
# [93 rows x 15 columns]

# %%
# Step 3: Algorithm to Estimate Audience Overlap
def estimate_overlap(df, demographic_column):
    """
    Estimates audience overlap for a given demographic characteristic.

    Args:
        df (pandas.DataFrame): The merged data with calculated lower bounds.
        demographic_column (str): The name of the demographic column to analyze.
    """
    pairs = df.groupby(['tag', demographic_column])[['lower_bound']].max().reset_index()

    # Estimate joint distribution
    joint_distribution = pairs.groupby(demographic_column)[['lower_bound']].mean()

    # Use the estimated joint distribution to refine the lower bound
    df['refined_lower_bound'] = df.apply(lambda row: max(row['lower_bound'], joint_distribution.loc[row[demographic_column]]['lower_bound']), axis=1)

# %%
# Apply the algorithm for each demographic characteristic
demographic_characteristics = ['browsers', 'resolutions', 'oses', 'languages']
for characteristic in demographic_characteristics:
    estimate_overlap(merged_data, characteristic)

# %%
print(merged_data[['tag', 'date', 'demo', 'Visitors', 'lower_bound', 'refined_lower_bound']])
# Out:
#                tag        date  \
# 0             AIF/  2022-12-01
# 1             AIF/  2022-12-02
# 2             AIF/  2022-12-03
# 3             AIF/  2022-12-04
# 4             AIF/  2022-12-05
# ..             ...         ...
# 88  kommersant.ru/  2022-12-27
# 89  kommersant.ru/  2022-12-28
# 90  kommersant.ru/  2022-12-29
# 91  kommersant.ru/  2022-12-30
# 92  kommersant.ru/  2022-12-31
#
#                                                  demo   Visitors  lower_bound  \
# 0   {'Men above 45': 270578.0, 'Men 25-34': 248189...  1387448.0    1387448.0
# 1   {'Men above 45': 242880.0, 'Men 25-34': 218607...  1224443.0    1224443.0
# 2   {'Men above 45': 215736.0, 'Men 25-34': 195687...  1108391.0    1108391.0
# 3   {'Men above 45': 205517.0, 'Men 25-34': 181038...  1071513.0    1071513.0
# 4   {'Men above 45': 215976.0, 'Men 25-34': 207819...  1174182.0    1174182.0
# ..                                                ...        ...          ...
# 88  {'Men 25-34': 327395.0, 'Men 18-24': 273582.0,...  1306594.0    1306594.0
# 89  {'Men 25-34': 318169.0, 'Men 18-24': 265664.0,...  1237120.0    1237120.0
# 90  {'Men 25-34': 337351.0, 'Men 18-24': 299877.0,...  1385526.0    1385526.0
# 91  {'Men 25-34': 315727.0, 'Men 18-24': 275097.0,...  1273358.0    1273358.0
# 92  {'Men 25-34': 262995.0, 'Men 18-24': 260051.0,...  1074313.0    1074313.0
#
#     refined_lower_bound
# 0             1387448.0
# 1             1224443.0
# 2             1108391.0
# 3             1071513.0
# 4             1174182.0
# ..                  ...
# 88            2137569.0
# 89            2137569.0
# 90            2137569.0
# 91            2137569.0
# 92            2137569.0
#
# [93 rows x 6 columns]

# %%
# Step 4: Save the results to a CSV file
"""
Save the final results to a CSV file named 'result.csv' without the index.
"""
result_file_path = './output/result.csv'
merged_data.to_csv(result_file_path, index=False)
